# %%
import sys, os
import casestudy2 as cs2
from os import listdir
import matplotlib

# %matplotlib inline

# %%
cs2.info_digest()
# Out:
# Net Revenue per Year : {2015: 29036749.189999994, 2016: 25730943.59, 2017: 31417495.030000016}
# Revenue from new customers : {2015: 'NA', 2016: 18245491.01, 2017: 28776235.039999995}
# Revenue from existing customers : {2015: 'NA', 2016: 7485452.58, 2017: 2641259.99}
# Total customers per year : {2015: 231294, 2016: 204646, 2017: 249987}
# How many new customers per year : {2015: 'NA', 2016: 145062, 2017: 229028}
# How many existing customers per year : {2015: 'NA', 2016: 59584, 2017: 20959}
# Existing Customer Growth : {2015: 'NA', 2016: 'NA', 2017: -4844192.59}
# Revenue per new customer : {2015: 'NA', 2016: 125.77719189036414, 2017: 125.64505230801473}
# Revenue per existing customer : {2015: 'NA', 2016: 125.62856773630504, 2017: 126.02032492008207}
# How many existing customers were lost each year : {2015: 'NA', 2016: 171710, 2017: 183687}

# %% [markdown]
# <table>
#   <tr>
#       <th>_</th>
#     <th>2015</th>
#     <th>2016</th>
#     <th>2017</th>
#   </tr>
#   <tr>
#       <td>Total Customers per Year</td>
#     <td>231294</td>
#     <td>204646</td>
#     <td>249987</td>
#   </tr>
#   <tr>
#       <td>New Customers per Year</td>
#     <td>NA</td>
#     <td>145062</td>
#     <td>229028</td>
#   </tr>
#   <tr>
#       <td>Existing Customers per Year</td>
#     <td>NA</td>
#     <td>59584</td>
#     <td>20959</td>
#   </tr>
#     <tr><td>Net Revenue per Year</td>
#         <td>29036749.19</td>
#         <td>25730943.59</td>
#         <td>31417495.03</td>
#     </tr>
#   <tr>
#       <td>Revenue from New Customers</td>
#     <td>NA</td>
#     <td>18245491.01</td>
#     <td>28776235.04</td>
#   </tr>
#           <tr>
#           <td>Revenue from Existing Customers</td>
#               <td>NA</td>
#               <td>7485452.58</td>
#               <td>2641259.99</td>
#     </tr>
#   <tr>
#     <td>Existing Customer Revenue Growth</td>
#       <td>NA</td>
#     <td>NA</td>
#     <td>-4844192</td>
#   </tr>
#   <tr>
#       <td>Customers Lost per Year</td>
#     <td>NA</td>
#     <td>171710</td>
#     <td>183687</td>
#   </tr>
#     <tr><td>Revenue per New Customer</td>
#         <td>NA</td>
#         <td>125.7771</td>
#         <td>125.6451</td>
#     </tr>
#     <tr><td>Revenue per Existing Customer</td>
#         <td>NA</td>
#         <td>125.6286</td>
#         <td>126.0203</td>
#     </tr>
# </table>
#
# New and existing customers don't seem to have any difference in their spending habits, at least not that can be determined form this data.

# %%
cs2.make_histograms()

# %% [markdown]
# The distribution of how many customers provided how much revenue per year is very constant with sharp cutoffs at 0 and 250 dollars. There is also not any meaningful change from year to year.

# %%
cs2.make_rev_share_bar_graph()

# %% [markdown]
# We see that the existing customer revenue has dramatically decreased form 2016 to 2017. This was more than offset by the increase in new customers, although I would still be a bit concerned about the dropoff of existing customers.
